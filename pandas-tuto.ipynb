# %%
import pandas as pd

train_cvs_path = "./train.csv"
train_csv = pd.read_csv(train_cvs_path)

# %%
train_csv.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
train_csv.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
train_csv.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
train_csv.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
train_csv['Age']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
train_csv.loc[4]
# Out:
# PassengerId                           5
# Survived                              0
# Pclass                                3
# Name           Allen, Mr. William Henry
# Sex                                male
# Age                                35.0
# SibSp                                 0
# Parch                                 0
# Ticket                           373450
# Fare                               8.05
# Cabin                               NaN
# Embarked                              S
# Name: 4, dtype: object

# %%
train_csv = train_csv.set_index('PassengerId')

# %%
train_csv.columns
# Out:
# Index(['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket',
#        'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
train_csv = train_csv[['Survived', 'Pclass', 'Sex', 'Age', 'SibSp',
       'Parch', 'Fare', 'Cabin', 'Embarked']]
train_csv
# Out:
#              Survived  Pclass     Sex   Age  SibSp  Parch     Fare Cabin  \
# PassengerId
# 1                   0       3    male  22.0      1      0   7.2500   NaN
# 2                   1       1  female  38.0      1      0  71.2833   C85
# 3                   1       3  female  26.0      0      0   7.9250   NaN
# 4                   1       1  female  35.0      1      0  53.1000  C123
# 5                   0       3    male  35.0      0      0   8.0500   NaN
# ...               ...     ...     ...   ...    ...    ...      ...   ...
# 887                 0       2    male  27.0      0      0  13.0000   NaN
# 888                 1       1  female  19.0      0      0  30.0000   B42
# 889                 0       3  female   NaN      1      2  23.4500   NaN
# 890                 1       1    male  26.0      0      0  30.0000  C148
# 891                 0       3    male  32.0      0      0   7.7500   NaN
#
#             Embarked
# PassengerId
# 1                  S
# ...

# %%
train_csv.shape
# Out:
# (891, 9)

# %%
train_csv.loc[train_csv["Survived"] != 0]
# Out:
#              Survived  Pclass     Sex   Age  SibSp  Parch     Fare Cabin  \
# PassengerId
# 2                   1       1  female  38.0      1      0  71.2833   C85
# 3                   1       3  female  26.0      0      0   7.9250   NaN
# 4                   1       1  female  35.0      1      0  53.1000  C123
# 9                   1       3  female  27.0      0      2  11.1333   NaN
# 10                  1       2  female  14.0      1      0  30.0708   NaN
# ...               ...     ...     ...   ...    ...    ...      ...   ...
# 876                 1       3  female  15.0      0      0   7.2250   NaN
# 880                 1       1  female  56.0      0      1  83.1583   C50
# 881                 1       2  female  25.0      0      1  26.0000   NaN
# 888                 1       1  female  19.0      0      0  30.0000   B42
# 890                 1       1    male  26.0      0      0  30.0000  C148
#
#             Embarked
# PassengerId
# 2                  C
# ...

# %%
train_csv.loc[train_csv["Survived"] == 0]
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare Cabin  \
# 0              1         0       3    male  22.0      1      0   7.2500   NaN
# 4              5         0       3    male  35.0      0      0   8.0500   NaN
# 5              6         0       3    male   NaN      0      0   8.4583   NaN
# 6              7         0       1    male  54.0      0      0  51.8625   E46
# 7              8         0       3    male   2.0      3      1  21.0750   NaN
# ..           ...       ...     ...     ...   ...    ...    ...      ...   ...
# 884          885         0       3    male  25.0      0      0   7.0500   NaN
# 885          886         0       3  female  39.0      0      5  29.1250   NaN
# 886          887         0       2    male  27.0      0      0  13.0000   NaN
# 888          889         0       3  female   NaN      1      2  23.4500   NaN
# 890          891         0       3    male  32.0      0      0   7.7500   NaN
#
#     Embarked
# 0          S
# ...

# %%
train_csv.query("Survived != 0")
# Out:
#              Survived  Pclass     Sex   Age  SibSp  Parch     Fare Cabin  \
# PassengerId
# 2                   1       1  female  38.0      1      0  71.2833   C85
# 3                   1       3  female  26.0      0      0   7.9250   NaN
# 4                   1       1  female  35.0      1      0  53.1000  C123
# 9                   1       3  female  27.0      0      2  11.1333   NaN
# 10                  1       2  female  14.0      1      0  30.0708   NaN
# ...               ...     ...     ...   ...    ...    ...      ...   ...
# 876                 1       3  female  15.0      0      0   7.2250   NaN
# 880                 1       1  female  56.0      0      1  83.1583   C50
# 881                 1       2  female  25.0      0      1  26.0000   NaN
# 888                 1       1  female  19.0      0      0  30.0000   B42
# 890                 1       1    male  26.0      0      0  30.0000  C148
#
#             Embarked
# PassengerId
# 2                  C
# ...

# %%
train_csv.loc[~train_csv["Cabin"].isna()]
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare  \
# 1              2         1       1  female  38.0      1      0  71.2833
# 3              4         1       1  female  35.0      1      0  53.1000
# 6              7         0       1    male  54.0      0      0  51.8625
# 10            11         1       3  female   4.0      1      1  16.7000
# 11            12         1       1  female  58.0      0      0  26.5500
# ..           ...       ...     ...     ...   ...    ...    ...      ...
# 871          872         1       1  female  47.0      1      1  52.5542
# 872          873         0       1    male  33.0      0      0   5.0000
# 879          880         1       1  female  56.0      0      1  83.1583
# 887          888         1       1  female  19.0      0      0  30.0000
# 889          890         1       1    male  26.0      0      0  30.0000
#
#            Cabin Embarked
# 1            C85        C
# 3           C123        S
# ...

# %%
train_csv["Age"].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
train_csv.plot(kind='scatter', x="Age", y='Fare')
# Out:
# <Axes: xlabel='Age', ylabel='Fare'>

# %%
train_csv.query("Fare > 200")
# Out:
#              Survived  Pclass     Sex   Age  SibSp  Parch      Fare  \
# PassengerId
# 28                  0       1    male  19.0      3      2  263.0000
# 89                  1       1  female  23.0      3      2  263.0000
# 119                 0       1    male  24.0      0      1  247.5208
# 259                 1       1  female  35.0      0      0  512.3292
# 300                 1       1  female  50.0      0      1  247.5208
# 312                 1       1  female  18.0      2      2  262.3750
# 342                 1       1  female  24.0      3      2  263.0000
# 378                 0       1    male  27.0      0      2  211.5000
# 381                 1       1  female  42.0      0      0  227.5250
# 439                 0       1    male  64.0      1      4  263.0000
# 528                 0       1    male   NaN      0      0  221.7792
# 558                 0       1    male   NaN      0      0  227.5250
# 680                 1       1    male  36.0      0      1  512.3292
# ...

# %%
train_csv.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
train_csv.query('Parch != 0')
# Out:
#              Survived  Pclass     Sex   Age  SibSp  Parch     Fare Cabin  \
# PassengerId
# 8                   0       3    male   2.0      3      1  21.0750   NaN
# 9                   1       3  female  27.0      0      2  11.1333   NaN
# 11                  1       3  female   4.0      1      1  16.7000    G6
# 14                  0       3    male  39.0      1      5  31.2750   NaN
# 17                  0       3    male   2.0      4      1  29.1250   NaN
# ...               ...     ...     ...   ...    ...    ...      ...   ...
# 872                 1       1  female  47.0      1      1  52.5542   D35
# 880                 1       1  female  56.0      0      1  83.1583   C50
# 881                 1       2  female  25.0      0      1  26.0000   NaN
# 886                 0       3  female  39.0      0      5  29.1250   NaN
# 889                 0       3  female   NaN      1      2  23.4500   NaN
#
#             Embarked
# PassengerId
# 8                  S
# ...
